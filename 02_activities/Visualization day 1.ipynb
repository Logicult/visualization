# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
import seaborn as sns

# getting ready by installing libraries

# %%
np.random.seed(101)
x = np.arange(50)
y = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.barh(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.hist(y)
# Out:
# (array([7., 6., 2., 3., 5., 4., 6., 7., 5., 5.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.plot(x,y)

ax.set_title('Net Revenue Growth Percentage Per Annum')
ax.set_xlabel('Revenue Growth Percent')
ax.set_ylabel('Years')
# Out:
# Text(0, 0.5, 'Years')

# %%
font1 = {'family':'calibri','color':'red','size':25}
font2 = {'family':'monospace','color':'blue','size':10}

fig, ax = plt.subplots(figsize = (7, 3))
ax.plot(x,y)

ax.set_title('Net Revenue', fontdict= font1, loc = 'left')
ax.set_xlabel('Net Revenue', fontdict= font2, loc = 'center')
ax.set_ylabel('Years', fontdict= font2)
# Out:
# Text(0, 0.5, 'Years')

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.scatter(x,
           y, marker = '*',
           color = 'indigo')

# %%
fig, ax = plt.subplots(figsize = (7, 3))
ax.plot(x,
           y, 
           marker = '*',
           color = 'indigo',
           linestyle = '--',
           linewidth = '2')

# %%
# incomplete moved too fast
fig, ax = plt.subplots(figsize = (7, 3))
ax.plot(x,y,
        marker = '*',
        markersize = 12,
        color = '#7425b9',
        linestyle = '--',
        linewidth = '2',
        markeredgecolor = '#fa9359',
        markerfacecolor = '#000000')

# %%
# incomplete moved too fast

fig, ax = plt.subplots(figsize = (7, 3))
ax.plot(x,y,
        marker = '*',
        markersize = 12,
        color = '#7425b9',
        linestyle = 'dashed',
        linewidth = '2',
        markeredgecolor = '#fa9359',
        markerfacecolor = '#000000')

ax.grid(axis = 'y')

# %%
# Activity was to change color and width etc of grid

fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y,
        marker='*',
        markersize=12,
        color='#7425b9',
        linestyle='dashed',
        linewidth='2',
        markeredgecolor='#fa9359',
        markerfacecolor='#000000')

ax.grid(axis='y', linestyle=':', linewidth=0.5, color='black')

# %%
# Activity was to Select one of the graph types from python graph gallery and see how it looks

# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]
 
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
 
# The position of the bars on the x-axis
r = [0,1,2,3,4]
 
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
 
# Create brown bars
plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the first ones
plt.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
 
# Show graphic
plt.show()

# %% [markdown]
# This was an exercise to comment on aesthetic, substantive and perceptual qualities of any particular data visulaization from python photo gallery.
#
# The data visulaization above is good because
#
# 1. Colors are distinct. visually appealing.
# 2. Text is clear.
# 3. Easy to compare each data point to the total value for each of A,B,C,D.
# 4. Same size of bars is easy for comparison and visually good.
# 5. No legend is not good.
